# %%
import pandas as pd

# %%
df=pd.read_csv('Marketing-Customer-Value-Analysis.csv')
df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        Number of Open Complaints  Number of Policies  Total Claim Amount
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678

# %%
df.isnull().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
df.drop(columns=['Customer','State','Effective To Date'],inplace=True)
df
# Out:
#       Customer Lifetime Value Response  Coverage Education EmploymentStatus  \
# 0                 2763.519279       No     Basic  Bachelor         Employed
# 1                 6979.535903       No  Extended  Bachelor       Unemployed
# 2                12887.431650       No   Premium  Bachelor         Employed
# 3                 7645.861827       No     Basic  Bachelor       Unemployed
# 4                 2813.692575       No     Basic  Bachelor         Employed
# ...                       ...      ...       ...       ...              ...
# 9129             23405.987980       No     Basic  Bachelor         Employed
# 9130              3096.511217      Yes  Extended   College         Employed
# 9131              8163.890428       No  Extended  Bachelor       Unemployed
# 9132              7524.442436       No  Extended   College         Employed
# 9133              2611.836866       No  Extended   College       Unemployed
#
#      Gender  Income Location Code Marital Status  Monthly Premium Auto  ...  \
# 0         F   56274      Suburban        Married                    69  ...
# 1         F       0      Suburban         Single                    94  ...
# 2         F   48767      Suburban        Married                   108  ...
# 3         M       0      Suburban        Married                   106  ...
# 4         M   43836         Rural         Single                    73  ...
# ...     ...     ...           ...            ...                   ...  ...
# 9129      M   71941         Urban        Married                    73  ...
# 9130      F   21604      Suburban       Divorced                    79  ...
# 9131      M       0      Suburban         Single                    85  ...
# 9132      M   21941      Suburban        Married                    96  ...
# 9133      M       0      Suburban         Single                    77  ...
#
#       Months Since Policy Inception  Number of Open Complaints  \
# 0                                 5                          0
# 1                                42                          0
# 2                                38                          0
# 3                                65                          0
# 4                                44                          0
# ...                             ...                        ...
# 9129                             89                          0
# 9130                             28                          0
# 9131                             37                          3
# 9132                              3                          0
# 9133                             90                          0
#
#       Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3           Offer1
# 1                      8   Personal Auto   Personal L3           Offer3
# 2                      2   Personal Auto   Personal L3           Offer1
# 3                      7  Corporate Auto  Corporate L2           Offer1
# 4                      1   Personal Auto   Personal L1           Offer1
# ...                  ...             ...           ...              ...
# 9129                   2   Personal Auto   Personal L1           Offer2
# 9130                   1  Corporate Auto  Corporate L3           Offer1
# 9131                   2  Corporate Auto  Corporate L2           Offer1
# 9132                   3   Personal Auto   Personal L2           Offer3
# 9133                   1  Corporate Auto  Corporate L3           Offer4
#
#      Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0            Agent         384.811147   Two-Door Car      Medsize
# 1            Agent        1131.464935  Four-Door Car      Medsize
# 2            Agent         566.472247   Two-Door Car      Medsize
# 3      Call Center         529.881344            SUV      Medsize
# 4            Agent         138.130879  Four-Door Car      Medsize
# ...            ...                ...            ...          ...
# 9129           Web         198.234764  Four-Door Car      Medsize
# 9130        Branch         379.200000  Four-Door Car      Medsize
# 9131        Branch         790.784983  Four-Door Car      Medsize
# 9132        Branch         691.200000  Four-Door Car        Large
# 9133   Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 21 columns]

# %%
df['EmploymentStatus'].value_counts()
# Out:
# EmploymentStatus
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['Customer Lifetime Value'])
plt.show()

# %%
df['Customer Lifetime Value'].hist(bins=50)
plt.show()

# %%
Q1 = df['Customer Lifetime Value'].quantile(0.25)
Q3 = df['Customer Lifetime Value'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_clean = df[(df['Customer Lifetime Value'] >= lower_bound) & 
              (df['Customer Lifetime Value'] <= upper_bound)]
print(df_clean.shape[0])
# Out:
# 8317

# %%
sns.boxplot(x=df_clean['Customer Lifetime Value'])
plt.title("After Removing Outliers")
plt.show()

# %%
x=df_clean.drop('Customer Lifetime Value',axis=1)
x
# Out:
#      Response  Coverage Education EmploymentStatus Gender  Income  \
# 0          No     Basic  Bachelor         Employed      F   56274
# 1          No  Extended  Bachelor       Unemployed      F       0
# 2          No   Premium  Bachelor         Employed      F   48767
# 3          No     Basic  Bachelor       Unemployed      M       0
# 4          No     Basic  Bachelor         Employed      M   43836
# ...       ...       ...       ...              ...    ...     ...
# 9128       No   Premium   College         Employed      F   47761
# 9130      Yes  Extended   College         Employed      F   21604
# 9131       No  Extended  Bachelor       Unemployed      M       0
# 9132       No  Extended   College         Employed      M   21941
# 9133       No  Extended   College       Unemployed      M       0
#
#      Location Code Marital Status  Monthly Premium Auto  \
# 0         Suburban        Married                    69
# 1         Suburban         Single                    94
# 2         Suburban        Married                   108
# 3         Suburban        Married                   106
# 4            Rural         Single                    73
# ...            ...            ...                   ...
# 9128      Suburban         Single                   104
# 9130      Suburban       Divorced                    79
# 9131      Suburban         Single                    85
# 9132      Suburban        Married                    96
# 9133      Suburban         Single                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9128                       16                             58
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       Number of Open Complaints  Number of Policies     Policy Type  \
# 0                             0                   1  Corporate Auto
# 1                             0                   8   Personal Auto
# 2                             0                   2   Personal Auto
# 3                             0                   7  Corporate Auto
# 4                             0                   1   Personal Auto
# ...                         ...                 ...             ...
# 9128                          0                   1   Personal Auto
# 9130                          0                   1  Corporate Auto
# 9131                          3                   2  Corporate Auto
# 9132                          0                   3   Personal Auto
# 9133                          0                   1  Corporate Auto
#
#             Policy Renew Offer Type Sales Channel  Total Claim Amount  \
# 0     Corporate L3           Offer1         Agent          384.811147
# 1      Personal L3           Offer3         Agent         1131.464935
# 2      Personal L3           Offer1         Agent          566.472247
# 3     Corporate L2           Offer1   Call Center          529.881344
# 4      Personal L1           Offer1         Agent          138.130879
# ...            ...              ...           ...                 ...
# 9128   Personal L2           Offer1        Branch          541.282007
# 9130  Corporate L3           Offer1        Branch          379.200000
# 9131  Corporate L2           Offer1        Branch          790.784983
# 9132   Personal L2           Offer3        Branch          691.200000
# 9133  Corporate L3           Offer4   Call Center          369.600000
#
#       Vehicle Class Vehicle Size
# 0      Two-Door Car      Medsize
# 1     Four-Door Car      Medsize
# 2      Two-Door Car      Medsize
# 3               SUV      Medsize
# 4     Four-Door Car      Medsize
# ...             ...          ...
# 9128  Four-Door Car        Large
# 9130  Four-Door Car      Medsize
# 9131  Four-Door Car      Medsize
# 9132  Four-Door Car        Large
# 9133   Two-Door Car      Medsize
#
# [8317 rows x 20 columns]

# %%
import numpy as np
y = np.log1p(df_clean['Customer Lifetime Value'])
y
# Out:
# 0       7.924622
# 1       8.850881
# 2       9.464085
# 3       8.942051
# 4       7.942608
#           ...
# 9128    8.319083
# 9130    8.038354
# 9131    9.007599
# 9132    8.926045
# 9133    7.868192
# Name: Customer Lifetime Value, Length: 8317, dtype: float64

# %%
df_clean.columns=df_clean.columns.str.strip()
df_clean
# Out:
#       Customer Lifetime Value Response  Coverage Education EmploymentStatus  \
# 0                 2763.519279       No     Basic  Bachelor         Employed
# 1                 6979.535903       No  Extended  Bachelor       Unemployed
# 2                12887.431650       No   Premium  Bachelor         Employed
# 3                 7645.861827       No     Basic  Bachelor       Unemployed
# 4                 2813.692575       No     Basic  Bachelor         Employed
# ...                       ...      ...       ...       ...              ...
# 9128              4100.398533       No   Premium   College         Employed
# 9130              3096.511217      Yes  Extended   College         Employed
# 9131              8163.890428       No  Extended  Bachelor       Unemployed
# 9132              7524.442436       No  Extended   College         Employed
# 9133              2611.836866       No  Extended   College       Unemployed
#
#      Gender  Income Location Code Marital Status  Monthly Premium Auto  ...  \
# 0         F   56274      Suburban        Married                    69  ...
# 1         F       0      Suburban         Single                    94  ...
# 2         F   48767      Suburban        Married                   108  ...
# 3         M       0      Suburban        Married                   106  ...
# 4         M   43836         Rural         Single                    73  ...
# ...     ...     ...           ...            ...                   ...  ...
# 9128      F   47761      Suburban         Single                   104  ...
# 9130      F   21604      Suburban       Divorced                    79  ...
# 9131      M       0      Suburban         Single                    85  ...
# 9132      M   21941      Suburban        Married                    96  ...
# 9133      M       0      Suburban         Single                    77  ...
#
#       Months Since Policy Inception  Number of Open Complaints  \
# 0                                 5                          0
# 1                                42                          0
# 2                                38                          0
# 3                                65                          0
# 4                                44                          0
# ...                             ...                        ...
# 9128                             58                          0
# 9130                             28                          0
# 9131                             37                          3
# 9132                              3                          0
# 9133                             90                          0
#
#       Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3           Offer1
# 1                      8   Personal Auto   Personal L3           Offer3
# 2                      2   Personal Auto   Personal L3           Offer1
# 3                      7  Corporate Auto  Corporate L2           Offer1
# 4                      1   Personal Auto   Personal L1           Offer1
# ...                  ...             ...           ...              ...
# 9128                   1   Personal Auto   Personal L2           Offer1
# 9130                   1  Corporate Auto  Corporate L3           Offer1
# 9131                   2  Corporate Auto  Corporate L2           Offer1
# 9132                   3   Personal Auto   Personal L2           Offer3
# 9133                   1  Corporate Auto  Corporate L3           Offer4
#
#      Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0            Agent         384.811147   Two-Door Car      Medsize
# 1            Agent        1131.464935  Four-Door Car      Medsize
# 2            Agent         566.472247   Two-Door Car      Medsize
# 3      Call Center         529.881344            SUV      Medsize
# 4            Agent         138.130879  Four-Door Car      Medsize
# ...            ...                ...            ...          ...
# 9128        Branch         541.282007  Four-Door Car        Large
# 9130        Branch         379.200000  Four-Door Car      Medsize
# 9131        Branch         790.784983  Four-Door Car      Medsize
# 9132        Branch         691.200000  Four-Door Car        Large
# 9133   Call Center         369.600000   Two-Door Car      Medsize
#
# [8317 rows x 21 columns]

# %%
num_col=x.select_dtypes(exclude='object').columns.tolist()
num_col
# Out:
# ['Income',
#  'Monthly Premium Auto',
#  'Months Since Last Claim',
#  'Months Since Policy Inception',
#  'Number of Open Complaints',
#  'Number of Policies',
#  'Total Claim Amount']

# %%
cat_col=x.select_dtypes(include='object').columns.tolist()
cat_col
# Out:
# ['Response',
#  'Coverage',
#  'Education',
#  'EmploymentStatus',
#  'Gender',
#  'Location Code',
#  'Marital Status',
#  'Policy Type',
#  'Policy',
#  'Renew Offer Type',
#  'Sales Channel',
#  'Vehicle Class',
#  'Vehicle Size']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %%
preprocessing=ColumnTransformer([
    ('num_col',StandardScaler(),num_col),
    ('cat_col',OneHotEncoder(handle_unknown='ignore'),cat_col)
])
preprocessing
# Out:
# ColumnTransformer(transformers=[('num_col', StandardScaler(),
#                                  ['Income', 'Monthly Premium Auto',
#                                   'Months Since Last Claim',
#                                   'Months Since Policy Inception',
#                                   'Number of Open Complaints',
#                                   'Number of Policies', 'Total Claim Amount']),
#                                 ('cat_col',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['Response', 'Coverage', 'Education',
#                                   'EmploymentStatus', 'Gender', 'Location Code',
#                                   'Marital Status', 'Policy Type', 'Policy',
#                                   'Renew Offer Type', 'Sales Channel',
#                                   'Vehicle Class', 'Vehicle Size'])])

# %%
from xgboost import XGBRegressor

# %%
pipeline=Pipeline([
    ('preprocessing',preprocessing),
    ('model',XGBRegressor(n_estimators=100,
    learning_rate=0.05,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1))
])
pipeline
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num_col', StandardScaler(),
#                                                   ['Income',
#                                                    'Monthly Premium Auto',
#                                                    'Months Since Last Claim',
#                                                    'Months Since Policy '
#                                                    'Inception',
#                                                    'Number of Open Complaints',
#                                                    'Number of Policies',
#                                                    'Total Claim Amount']),
#                                                  ('cat_col',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Response', 'Coverage',
#                                                    'Education',
#                                                    'EmploymentStatus', 'Ge...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.05,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=5, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=100, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(pipeline, x, y, cv=5, scoring='r2')
print(scores.mean())
# Out:
# 0.9761128515252567

# %%
pipeline.fit(x_train,y_train)
y_pred=pipeline.predict(x_test)
y_pred
# Out:
# array([8.596737, 8.516489, 9.05894 , ..., 9.049627, 9.043953, 9.019305],
#       shape=(2496,), dtype=float32)

# %%
y_test
# Out:
# 1401    8.618599
# 8985    8.497833
# 4073    9.191925
# 3891    7.895031
# 7469    8.494701
#           ...
# 3739    8.493372
# 6368    9.231116
# 5999    9.065026
# 4196    9.049097
# 5075    8.914885
# Name: Customer Lifetime Value, Length: 2496, dtype: float64

# %%
from sklearn.metrics import accuracy_score,r2_score, mean_squared_error, mean_absolute_error
print('R2 Score:',r2_score(y_test,y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.9717851137923744
# MSE: 0.007459065136192451
# MAE: 0.03917059323970273

# %%
import joblib
joblib.dump(pipeline,'ibm_clv.pkl')
# Out:
# ['ibm_clv.pkl']

# %%
loaded = joblib.load("ibm_clv.pkl")

print("success")
print(type(loaded))
# Out:
# success
# <class 'sklearn.pipeline.Pipeline'>

# %%
import sys
import xgboost
import sklearn

print(sys.executable)
print(xgboost.__version__)
print(sklearn.__version__)
# Out:
# C:\Users\dell\AppData\Local\Programs\Python\Python310\python.exe
# 3.2.0
# 1.7.2
